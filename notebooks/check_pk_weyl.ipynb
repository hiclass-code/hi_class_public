# %%
import hiclassy

# %%
cosmo = hiclassy.HiClass()

params = {
    "output": "mPk,wPk",
    "z_max_pk": 10.0,
}

cosmo.set(params)
cosmo.compute()

# %%
cosmo.pk_weyl(0.1, 0.1)
# Out:
# 6.596825158138635e-12
